# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
helix=pd.read_csv("./TopFeatures.csv")
h1=helix
print(helix)
h2=pd.read_csv("./heatMaps.csv")
helix['value']=h2
#helix=pd.concat([helix,h2])
print(helix)
helix.to_csv("Finalmaps.csv",index=None,header=None)

g1=pd.read_csv("./Finalmaps.csv",index_col=None)
h5=helix['0'].to_numpy()
h6=helix['value'].to_numpy()
h5=np.reshape(h5, (50, 1)) # C-like index ordering

h6=np.reshape(h6, (50, 1)) # C-like index ordering
print(g1)
print(h6)
#print(h5)
#helix=helix[header=None]
# Out:
#                 0
# 0          AU12_c
# 1          AU04_c
# 2          AU12_r
# 3          AU04_r
# 4          AU05_c
# 5          AU14_c
# 6          AU06_c
# 7          AU06_r
# 8          AU14_r
# 9          AU07_r
# 10            p_8
# 11         AU10_c
# 12            p_2
# 13         AU10_r
# 14            p_0
# 15           p_23
# 16            p_7
# 17            p_6
# 18           p_10
# 19         AU01_r
# 20         AU25_r
# 21           p_24
# 22           p_12
# 23           p_11
# 24         AU17_r
# 25         AU09_r
# 26         AU26_r
# 27            p_9
# 28         AU45_r
# 29           p_20
# 30         AU05_r
# 31         AU23_r
# 32           p_13
# 33           p_19
# 34           p_33
# 35   gaze_angle_y
# 36            p_5
# 37         AU02_r
# 38           p_26
# 39           p_18
# 40           p_16
# 41       gaze_1_y
# 42           p_32
# 43         AU07_c
# 44         AU15_c
# 45         AU15_r
# 46           p_30
# 47           p_31
# 48         AU20_r
# 49            p_4
#                 0     value
# 0          AU12_c  0.032226
# 1          AU04_c  0.021694
# 2          AU12_r  0.020491
# 3          AU04_r  0.017065
# 4          AU05_c  0.016055
# 5          AU14_c  0.010919
# 6          AU06_c  0.007094
# 7          AU06_r  0.004737
# 8          AU14_r  0.004394
# 9          AU07_r  0.004171
# 10            p_8  0.004004
# 11         AU10_c  0.003910
# 12            p_2  0.003619
# 13         AU10_r  0.003395
# 14            p_0  0.002688
# 15           p_23  0.002667
# 16            p_7  0.002653
# 17            p_6  0.002558
# 18           p_10  0.002499
# 19         AU01_r  0.002310
# 20         AU25_r  0.002306
# 21           p_24  0.002273
# 22           p_12  0.002272
# 23           p_11  0.002191
# 24         AU17_r  0.002161
# 25         AU09_r  0.002148
# 26         AU26_r  0.002131
# 27            p_9  0.002131
# 28         AU45_r  0.002130
# 29           p_20  0.002125
# 30         AU05_r  0.002104
# 31         AU23_r  0.002102
# 32           p_13  0.002085
# 33           p_19  0.002083
# 34           p_33  0.002059
# 35   gaze_angle_y  0.002050
# 36            p_5  0.002040
# 37         AU02_r  0.001999
# 38           p_26  0.001986
# 39           p_18  0.001982
# 40           p_16  0.001961
# 41       gaze_1_y  0.001948
# 42           p_32  0.001943
# 43         AU07_c  0.001928
# 44         AU15_c  0.001921
# 45         AU15_r  0.001910
# 46           p_30  0.001899
# 47           p_31  0.001879
# 48         AU20_r  0.001872
# 49            p_4  0.001870
#            AU12_c  0.0322255611213556
# 0          AU04_c            0.021694
# 1          AU12_r            0.020491
# 2          AU04_r            0.017065
# 3          AU05_c            0.016055
# 4          AU14_c            0.010919
# 5          AU06_c            0.007094
# 6          AU06_r            0.004737
# 7          AU14_r            0.004394
# 8          AU07_r            0.004171
# 9             p_8            0.004004
# 10         AU10_c            0.003910
# 11            p_2            0.003619
# 12         AU10_r            0.003395
# 13            p_0            0.002688
# 14           p_23            0.002667
# 15            p_7            0.002653
# 16            p_6            0.002558
# 17           p_10            0.002499
# 18         AU01_r            0.002310
# 19         AU25_r            0.002306
# 20           p_24            0.002273
# 21           p_12            0.002272
# 22           p_11            0.002191
# 23         AU17_r            0.002161
# 24         AU09_r            0.002148
# 25         AU26_r            0.002131
# 26            p_9            0.002131
# 27         AU45_r            0.002130
# 28           p_20            0.002125
# 29         AU05_r            0.002104
# 30         AU23_r            0.002102
# 31           p_13            0.002085
# 32           p_19            0.002083
# 33           p_33            0.002059
# 34   gaze_angle_y            0.002050
# 35            p_5            0.002040
# 36         AU02_r            0.001999
# 37           p_26            0.001986
# 38           p_18            0.001982
# 39           p_16            0.001961
# 40       gaze_1_y            0.001948
# 41           p_32            0.001943
# 42         AU07_c            0.001928
# 43         AU15_c            0.001921
# 44         AU15_r            0.001910
# 45           p_30            0.001899
# 46           p_31            0.001879
# 47         AU20_r            0.001872
# 48            p_4            0.001870
# [[0.03222556]
#  [0.02169431]
#  [0.02049099]
#  [0.01706533]
#  [0.01605494]
#  [0.01091855]
#  [0.00709353]
#  [0.00473739]
#  [0.0043944 ]
#  [0.00417127]
#  [0.00400429]
#  [0.00390962]
#  [0.00361897]
#  [0.0033946 ]
#  [0.00268809]
#  [0.00266734]
#  [0.00265311]
#  [0.00255819]
#  [0.00249879]
#  [0.00231   ]
#  [0.00230591]
#  [0.00227307]
#  [0.00227212]
#  [0.00219078]
#  [0.00216083]
#  [0.00214805]
#  [0.002131  ]
#  [0.00213079]
#  [0.00213011]
#  [0.00212478]
#  [0.00210378]
#  [0.00210161]
#  [0.00208536]
#  [0.00208322]
#  [0.0020591 ]
#  [0.00204986]
#  [0.00204034]
#  [0.00199873]
#  [0.00198605]
#  [0.00198197]
#  [0.00196078]
#  [0.0019478 ]
#  [0.00194258]
#  [0.001928  ]
#  [0.00192132]
#  [0.00191045]
#  [0.00189905]
#  [0.00187894]
#  [0.00187202]
#  [0.00186981]]

# %%
print(h2.ndim)
print(h2['0'])
h2=h2.to_numpy()
print(h2)
type(h2)
# Out:
# 2
# 0     0.032226
# 1     0.021694
# 2     0.020491
# 3     0.017065
# 4     0.016055
# 5     0.010919
# 6     0.007094
# 7     0.004737
# 8     0.004394
# 9     0.004171
# 10    0.004004
# 11    0.003910
# 12    0.003619
# 13    0.003395
# 14    0.002688
# 15    0.002667
# 16    0.002653
# 17    0.002558
# 18    0.002499
# 19    0.002310
# 20    0.002306
# 21    0.002273
# 22    0.002272
# 23    0.002191
# 24    0.002161
# 25    0.002148
# 26    0.002131
# 27    0.002131
# 28    0.002130
# 29    0.002125
# 30    0.002104
# 31    0.002102
# 32    0.002085
# 33    0.002083
# 34    0.002059
# 35    0.002050
# 36    0.002040
# 37    0.001999
# 38    0.001986
# 39    0.001982
# 40    0.001961
# 41    0.001948
# 42    0.001943
# 43    0.001928
# 44    0.001921
# 45    0.001910
# 46    0.001899
# 47    0.001879
# 48    0.001872
# 49    0.001870
# Name: 0, dtype: float64
# [[0.03222556]
#  [0.02169431]
#  [0.02049099]
#  [0.01706533]
#  [0.01605494]
#  [0.01091855]
#  [0.00709353]
#  [0.00473739]
#  [0.0043944 ]
#  [0.00417127]
#  [0.00400429]
#  [0.00390962]
#  [0.00361897]
#  [0.0033946 ]
#  [0.00268809]
#  [0.00266734]
#  [0.00265311]
#  [0.00255819]
#  [0.00249879]
#  [0.00231   ]
#  [0.00230591]
#  [0.00227307]
#  [0.00227212]
#  [0.00219078]
#  [0.00216083]
#  [0.00214805]
#  [0.002131  ]
#  [0.00213079]
#  [0.00213011]
#  [0.00212478]
#  [0.00210378]
#  [0.00210161]
#  [0.00208536]
#  [0.00208322]
#  [0.0020591 ]
#  [0.00204986]
#  [0.00204034]
#  [0.00199873]
#  [0.00198605]
#  [0.00198197]
#  [0.00196078]
#  [0.0019478 ]
#  [0.00194258]
#  [0.001928  ]
#  [0.00192132]
#  [0.00191045]
#  [0.00189905]
#  [0.00187894]
#  [0.00187202]
#  [0.00186981]]
# numpy.ndarray

# %%
helix.columns
print(helix['0'])
print(helix['value'])
# Out:
# 0            AU12_c
# 1            AU04_c
# 2            AU12_r
# 3            AU04_r
# 4            AU05_c
# 5            AU14_c
# 6            AU06_c
# 7            AU06_r
# 8            AU14_r
# 9            AU07_r
# 10              p_8
# 11           AU10_c
# 12              p_2
# 13           AU10_r
# 14              p_0
# 15             p_23
# 16              p_7
# 17              p_6
# 18             p_10
# 19           AU01_r
# 20           AU25_r
# 21             p_24
# 22             p_12
# 23             p_11
# 24           AU17_r
# 25           AU09_r
# 26           AU26_r
# 27              p_9
# 28           AU45_r
# 29             p_20
# 30           AU05_r
# 31           AU23_r
# 32             p_13
# 33             p_19
# 34             p_33
# 35     gaze_angle_y
# 36              p_5
# 37           AU02_r
# 38             p_26
# 39             p_18
# 40             p_16
# 41         gaze_1_y
# 42             p_32
# 43           AU07_c
# 44           AU15_c
# 45           AU15_r
# 46             p_30
# 47             p_31
# 48           AU20_r
# 49              p_4
# Name: 0, dtype: object
# 0     0.032226
# 1     0.021694
# 2     0.020491
# 3     0.017065
# 4     0.016055
# 5     0.010919
# 6     0.007094
# 7     0.004737
# 8     0.004394
# 9     0.004171
# 10    0.004004
# 11    0.003910
# 12    0.003619
# 13    0.003395
# 14    0.002688
# 15    0.002667
# 16    0.002653
# 17    0.002558
# 18    0.002499
# 19    0.002310
# 20    0.002306
# 21    0.002273
# 22    0.002272
# 23    0.002191
# 24    0.002161
# 25    0.002148
# 26    0.002131
# 27    0.002131
# 28    0.002130
# 29    0.002125
# 30    0.002104
# 31    0.002102
# 32    0.002085
# 33    0.002083
# 34    0.002059
# 35    0.002050
# 36    0.002040
# 37    0.001999
# 38    0.001986
# 39    0.001982
# 40    0.001961
# 41    0.001948
# 42    0.001943
# 43    0.001928
# 44    0.001921
# 45    0.001910
# 46    0.001899
# 47    0.001879
# 48    0.001872
# 49    0.001870
# Name: value, dtype: float64

# %%
couple_columns=helix[['0','value']]
couple_columns.head()
# Out:
#          0     value
# 0   AU12_c  0.032226
# 1   AU04_c  0.021694
# 2   AU12_r  0.020491
# 3   AU04_r  0.017065
# 4   AU05_c  0.016055

# %%
plt.figure(figsize=(50,50))
ax=sns.heatmap(h6, annot=True,cmap="coolwarm",yticklabels=helix["0"]).set_title('co-relate')
plt.tight_layout()
plt.show()
